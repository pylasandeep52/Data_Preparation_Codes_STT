# %%
import os
os.environ["HF_HOME"] = "//mnt/data/stt/Datasets/Datasets/huggingface-cache"
os.environ["HF_DATASETS_CACHE"] = f"{os.environ['HF_HOME']}/datasets"
os.environ["TRANSFORMERS_CACHE"] = f"{os.environ['HF_HOME']}/transformers"
os.environ["HF_METRICS_CACHE"] = f"{os.environ['HF_HOME']}/metrics"
print("HF_DATASETS_CACHE:", os.environ["HF_DATASETS_CACHE"])
# Out:
# HF_DATASETS_CACHE: //mnt/data/stt/Datasets/Datasets/huggingface-cache/datasets

# %%
import pandas as pd
import numpy as np
import os
from datasets import load_dataset, Audio
import shutil
import soundfile as sf
from tqdm import tqdm
from IPython.display import Audio, display

# %%
os.getcwd()
# Out:
# '/mnt/data/stt/Datasets/Datasets'

# %%
from datasets import load_dataset
kathbath = load_dataset("ai4bharat/Kathbath", "punjabi", split="train")
# Out:
# Resolving data files:   0%|          | 0/22 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/30 [00:00<?, ?it/s]
# valid-00000-of-00002.parquet:   0%|          | 0.00/286M [00:00<?, ?B/s]
# valid-00001-of-00002.parquet:   0%|          | 0.00/302M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0/30 [00:00<?, ?files/s]
# train-00000-of-00030.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# train-00001-of-00030.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# train-00002-of-00030.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# train-00003-of-00030.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# train-00004-of-00030.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# train-00005-of-00030.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# train-00006-of-00030.parquet:   0%|          | 0.00/478M [00:00<?, ?B/s]
# train-00007-of-00030.parquet:   0%|          | 0.00/482M [00:00<?, ?B/s]
# train-00008-of-00030.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# train-00009-of-00030.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# train-00010-of-00030.parquet:   0%|          | 0.00/478M [00:00<?, ?B/s]
# train-00011-of-00030.parquet:   0%|          | 0.00/484M [00:00<?, ?B/s]
# train-00012-of-00030.parquet:   0%|          | 0.00/483M [00:00<?, ?B/s]
# train-00013-of-00030.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# train-00014-of-00030.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# train-00015-of-00030.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# train-00016-of-00030.parquet:   0%|          | 0.00/478M [00:00<?, ?B/s]
# train-00017-of-00030.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# train-00018-of-00030.parquet:   0%|          | 0.00/478M [00:00<?, ?B/s]
# train-00019-of-00030.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# train-00020-of-00030.parquet:   0%|          | 0.00/478M [00:00<?, ?B/s]
# train-00021-of-00030.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# train-00022-of-00030.parquet:   0%|          | 0.00/479M [00:00<?, ?B/s]
# train-00023-of-00030.parquet:   0%|          | 0.00/478M [00:00<?, ?B/s]
# train-00024-of-00030.parquet:   0%|          | 0.00/480M [00:00<?, ?B/s]
# train-00025-of-00030.parquet:   0%|          | 0.00/487M [00:00<?, ?B/s]
# train-00026-of-00030.parquet:   0%|          | 0.00/486M [00:00<?, ?B/s]
# train-00027-of-00030.parquet:   0%|          | 0.00/504M [00:00<?, ?B/s]
# train-00028-of-00030.parquet:   0%|          | 0.00/512M [00:00<?, ?B/s]
# train-00029-of-00030.parquet:   0%|          | 0.00/511M [00:00<?, ?B/s]
# Generating valid split:   0%|          | 0/3256 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/83298 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
print(kathbath)
# Out:
# Dataset({
#     features: ['fname', 'text', 'audio_filepath', 'lang', 'duration', 'gender', 'speaker_id'],
#     num_rows: 83298
# })

# %%
print(kathbath.column_names)
# Out:
# ['fname', 'text', 'audio_filepath', 'lang', 'duration', 'gender', 'speaker_id']

# %%
print(kathbath[0])
# Out:
# {'fname': '844424930443097-930-f.m4a', 'text': 'ਛਾਤੀ ਦਾ ਦੁੱਧ ਦੁਆਰਾ ਬੱਚੇ ਨੂੰ ਜ਼ਰੂਰੀ ਪੌਸ਼ਟਿਕ ਪ੍ਰਾਪਤ ਕਰਦਾ ਹੈ', 'audio_filepath': {'path': '844424930443097-930-f.flac', 'array': array([ 0.        ,  0.        ,  0.        , ..., -0.00025451,
#        -0.00020814, -0.00018835], shape=(105883,)), 'sampling_rate': 16000}, 'lang': 'pa', 'duration': 6.6176875, 'gender': 'Female', 'speaker_id': 930}

# %% [markdown]
# **from extraction to saving final csv pipeline**

# %%
class KathbathProcessor:
    def __init__(self, save_dir):
        self.save_dir = save_dir
        self.audio_folder = os.path.join(save_dir, "Kathbath_punjabi_audio")
        self.final_audio_folder = os.path.join(save_dir, "punjabi_audios_kathbath_final")
        self.raw_csv_path = os.path.join(save_dir, "kathbath_punjabi_metadata.csv")
        self.filtered_csv_path = os.path.join(save_dir, "filtered_punjabi_kathbath.csv")
        os.makedirs(self.audio_folder, exist_ok=True)
        os.makedirs(self.final_audio_folder, exist_ok=True)

    def load_dataset(self):
        return load_dataset("ai4bharat/Kathbath", "punjabi", split="train")

    def save_audio_and_metadata(self, dataset):
        data = []
        for idx in tqdm(range(len(dataset)), desc="Saving audio"):
            sample = dataset[idx]
            audio_array = sample["audio_filepath"]["array"]
            sr = sample["audio_filepath"]["sampling_rate"]
            duration_sec = len(audio_array) / sr
            duration_ms = duration_sec * 1000

            filename = f"kathbath_pa_{idx}.wav"
            filepath = os.path.join(self.audio_folder, filename)
            sf.write(filepath, audio_array, samplerate=sr)

            data.append({
                "audio_filename": filename,
                "text": sample["text"],
                "duration": sample["duration"],
                "duration_sec": duration_sec,
                "duration_ms": duration_ms
            })

        df = pd.DataFrame(data)
        df.to_csv(self.raw_csv_path, index=False)
        print(f" Saved metadata to {self.raw_csv_path}")
        return df

    def validate_and_update_csv(self, df):
        audio_files_set = set(os.listdir(self.audio_folder))
        unique_df = df.drop_duplicates(subset=["audio_filename"]).copy()
        unique_df["found"] = unique_df["audio_filename"].apply(lambda x: "yes" if x in audio_files_set else "no")
        unique_df.rename(columns={
            "audio_filename": "path",
            "text": "sentence"
        }, inplace=True)

        # Move 'found' after 'sentence'
        found = unique_df.pop("found")
        unique_df.insert(unique_df.columns.get_loc("sentence") + 1, "found", found)

        print(" Unique files checked and updated.")
        return unique_df

    def filter_by_duration(self, df, max_duration=15.0):
        filtered = df[df["duration_sec"] <= max_duration].copy()
        filtered.to_csv(self.filtered_csv_path, index=False)
        print(f" Filtered metadata saved to {self.filtered_csv_path}")
        return filtered

    def copy_filtered_audios(self, df):
        for fname in tqdm(df["path"], desc="Copying filtered audio files"):
            src = os.path.join(self.audio_folder, fname)
            dst = os.path.join(self.final_audio_folder, fname)
            if os.path.exists(src):
                os.system(f'cp "{src}" "{dst}"')

    def compare_duration_columns(self, df):
        if "duration" in df.columns and all(df["duration"].round(3) == df["duration_sec"].round(3)):
            print(" 'duration' and 'duration_sec' are same — dropping 'duration'")
            df = df.drop(columns=["duration"])
        else:
            print(" 'duration' and 'duration_sec' differ — keeping both")
        return df

    def summarize_csv(self, df, label=""):
        print(f"\n Summary of {label} Dataset:")
        print("-" * 40)
        print("Head:\n", df.head())
        print("\nTail:\n", df.tail())
        print("\nInfo:")
        print(df.info())
        print("\nDescribe:\n", df.describe())
        print("\nUnique 'path' count:", df["path"].nunique())

        print("\n Total Durations:")
        if "duration" in df.columns:
            print("Sum of 'duration' (sec):", df["duration"].sum())
        print("Sum of 'duration_sec':", df["duration_sec"].sum())
        print("Sum of 'duration_ms':", df["duration_ms"].sum())

        return df


processor = KathbathProcessor("/mnt/data/stt/Datasets/Datasets")
dataset = processor.load_dataset()
df_raw = processor.save_audio_and_metadata(dataset)
df_validated = processor.validate_and_update_csv(df_raw)
df_filtered = processor.filter_by_duration(df_validated)
processor.copy_filtered_audios(df_filtered)
df_final = processor.compare_duration_columns(df_filtered)
df_final = processor.summarize_csv(df_final, label="Final Filtered")

# Save final cleaned filtered CSV again (after possibly dropping column)
df_final.to_csv(processor.filtered_csv_path, index=False)
print(f"\n Final updated CSV saved to {processor.filtered_csv_path}")
# Out:
# Resolving data files:   0%|          | 0/22 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/30 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/30 [00:00<?, ?it/s]
# Saving audio: 100%|██████████| 83298/83298 [06:28<00:00, 214.49it/s]
#  Saved metadata to /mnt/data/stt/Datasets/Datasets/kathbath_punjabi_metadata.csv
#  Unique files checked and updated.
#  Filtered metadata saved to /mnt/data/stt/Datasets/Datasets/filtered_punjabi_kathbath.csv
# Copying filtered audio files: 100%|██████████| 83292/83292 [04:31<00:00, 307.29it/s]
#  'duration' and 'duration_sec' differ — keeping both
#
#  Summary of Final Filtered Dataset:
# ----------------------------------------
# Head:
#                  path                                           sentence found  \
# 0  kathbath_pa_0.wav  ਛਾਤੀ ਦਾ ਦੁੱਧ ਦੁਆਰਾ ਬੱਚੇ ਨੂੰ ਜ਼ਰੂਰੀ ਪੌਸ਼ਟਿਕ ਪ੍ਰ...   yes
# 1  kathbath_pa_1.wav              ਅਤੇ ਇਸ ਨੂੰ ਅਕਸਰ ਕਾਰਵਾਈ ਦੀ ਕੀਮਤ ਨਹੀ ਹੈ   yes
# 2  kathbath_pa_2.wav      ਪੋਸਟ ਦੀ ਲੰਬਾਈ ਦਾ ਇੱਕ ਤਿਹਾਈ ਬੁੱਧੀਮਾਨ ਚਾਹੀਦਾ ਹੈ   yes
# 3  kathbath_pa_3.wav  ਮਸਾਜ ਸ਼ੁਰੂ ਕਰਨ ਦੇ ਅੱਗੇ ਦੀ ਚਮੜੀ ਨੂੰ ਸਾਫ਼ ਕਰਨ ਲਈ...   yes
# 4  kathbath_pa_4.wav             ਧਰਤੀ ਦੇ ਉਪਰਲੇ ਪਰਤ ਦਾ ਤਾਪਮਾਨ ਵਧ ਰਿਹਾ ਹੈ   yes
#
#    duration  duration_sec  duration_ms
# 0  6.617687      6.617687    6617.6875
# 1  2.693500      2.693500    2693.5000
# 2  4.992312      4.992312    4992.3125
# 3  5.015500      5.015500    5015.5000
# 4  2.298812      2.298812    2298.8125
#
# Tail:
#                          path  \
# 83293  kathbath_pa_83293.wav
# 83294  kathbath_pa_83294.wav
# 83295  kathbath_pa_83295.wav
# 83296  kathbath_pa_83296.wav
# 83297  kathbath_pa_83297.wav
#
#                                                 sentence found  duration  \
# 83293  ਜਵਾਨੀ ਵਿੱਚ ਪੈਰ ਧਰਦਿਆਂ ਆਪ ਨੇ ਸ਼ਸਤਰ ਵਿੱਦਿਆ ਦੀ ਸਿ...   yes  6.269375
# 83294  ਲੇਖਕ ਦੱਸਦਾ ਹੈ ਕਿ ਪੰਜਾਬੀ ਦੇ ਆਰੰਭਲੇ ਖੋਜ ਕਾਰਜ ਪੰਜ...   yes  5.503125
# 83295        ਵਾਕ ਚ ਸੰਧੀ ਕਰਨ ਦੀ ਥਾਂ ਸੰਧੀ ਨਾ ਕਰਨਾ ਵਿਸ਼ਲੇਸ਼   yes  7.592937
# 83296  ਤੀਸਰੀ ਕਸਮ ਵਿੱਚ ਉਸਨੇ ਬਾਸੂ ਭੱਟਾਚਾਰੀਆ ਦੇ ਸਹਾਇਕ ਨਿ...   yes  6.617687
# 83297             ਇਸ ਕਹਾਣੀ ਵਿੱਚ ਜੋਗੀਆਂ ਨੂੰ ਦਿਖਾਇਆ ਗਿਆ ਹੈ   yes  6.478375
#
#        duration_sec  duration_ms
# 83293      6.269375    6269.3750
# 83294      5.503125    5503.1250
# 83295      7.592937    7592.9375
# 83296      6.617687    6617.6875
# 83297      6.478375    6478.3750
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83292 entries, 0 to 83297
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   path          83292 non-null  object
#  1   sentence      83292 non-null  object
#  2   found         83292 non-null  object
#  3   duration      83292 non-null  float64
#  4   duration_sec  83292 non-null  float64
#  5   duration_ms   83292 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 4.4+ MB
# None
#
# Describe:
#             duration  duration_sec   duration_ms
# count  83292.000000  83292.000000  83292.000000
# mean       5.331542      5.331542   5331.542365
# std        1.363655      1.363655   1363.655007
# min        1.021688      1.021688   1021.687500
# 25%        4.365375      4.365375   4365.375000
# 50%        5.131625      5.131625   5131.625000
# 75%        6.083625      6.083625   6083.625000
# max       14.953687     14.953687  14953.687500
#
# Unique 'path' count: 83292
#
#  Total Durations:
# Sum of 'duration' (sec): 444074.8266875
# Sum of 'duration_sec': 444074.8266875
# Sum of 'duration_ms': 444074826.6875
#
#  Final updated CSV saved to /mnt/data/stt/Datasets/Datasets/filtered_punjabi_kathbath.csv

# %% [markdown]
# **Dropping duration column**

# %%
csv_path = "/mnt/data/stt/Datasets/Datasets/filtered_punjabi_kathbath.csv" # Load the CSV file
df = pd.read_csv(csv_path)


print(f" Total columns before dropping: {df.shape[1]}") # Show total number of columns before dropping
print(" Column names:", df.columns.tolist())


if 'duration' in df.columns: # Drop the 'duration' column if it exists
    df.drop(columns=['duration'], inplace=True)
    print(" 'duration' column dropped.")
else:
    print(" 'duration' column not found.")


print(f" Total columns after dropping: {df.shape[1]}") # Show total columns after dropping
print(" Updated column names:", df.columns.tolist())
# Out:
#  Total columns before dropping: 6
#  Column names: ['path', 'sentence', 'found', 'duration', 'duration_sec', 'duration_ms']
#  'duration' column dropped.
#  Total columns after dropping: 5
#  Updated column names: ['path', 'sentence', 'found', 'duration_sec', 'duration_ms']

# %%
df.to_csv(csv_path, index=False)
print(" Updated CSV saved.")
# Out:
#  Updated CSV saved.

# %% [markdown]
# **For updated audio folder**

# %%
audio_folder = "/mnt/data/stt/Datasets/Datasets/punjabi_audios_kathbath_final"
# List all .wav files
audio_files = [f for f in os.listdir(audio_folder) if f.endswith(".wav")]
# Count them
print(f" Total number of audio files: {len(audio_files)}")
# Out:
#  Total number of audio files: 83292

# %%
import os
from IPython.display import Audio
audio_files = sorted(os.listdir(audio_folder))[:5]  # first 5 files
for file in audio_files:
    print(f" Playing: {file}")
    display(Audio(filename=os.path.join(audio_folder, file)))
# Out:
#  Playing: kathbath_pa_0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Playing: kathbath_pa_1.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Playing: kathbath_pa_10.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Playing: kathbath_pa_100.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Playing: kathbath_pa_1000.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
