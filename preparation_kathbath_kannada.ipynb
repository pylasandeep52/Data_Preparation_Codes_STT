# %%
import pandas as pd
import numpy as np
import os
from datasets import load_dataset, Audio
import shutil
import soundfile as sf
from tqdm import tqdm
from IPython.display import Audio, display

# %%
os.getcwd()
# Out:
# '/mnt/data/stt/Datasets/Datasets'

# %%
rm -rf ~/.cache/huggingface

# %%
import os
# Set Hugging Face cache to /mnt/data
os.environ["HF_HOME"] = "/mnt/data/stt/Datasets/Datasets/huggingface"
os.environ["HF_DATASETS_CACHE"] = "/mnt/data/stt/Datasets/Datasets/huggingface/datasets"
os.environ["TRANSFORMERS_CACHE"] = "/mnt/data/stt/Datasets/Datasets/huggingface/transformers"
os.environ["HF_METRICS_CACHE"] = "/mnt/data/stt/Datasets/Datasets/huggingface/metrics"

from datasets import load_dataset
kathbath = load_dataset("ai4bharat/Kathbath", "kannada", split="train")
# Out:
# README.md:   0%|          | 0.00/10.0k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/22 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/33 [00:00<?, ?it/s]
# valid-00000-of-00002.parquet:   0%|          | 0.00/255M [00:00<?, ?B/s]
# valid-00001-of-00002.parquet:   0%|          | 0.00/287M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0/33 [00:00<?, ?files/s]
# train-00000-of-00033.parquet:   0%|          | 0.00/487M [00:00<?, ?B/s]
# train-00001-of-00033.parquet:   0%|          | 0.00/498M [00:00<?, ?B/s]
# train-00002-of-00033.parquet:   0%|          | 0.00/494M [00:00<?, ?B/s]
# train-00003-of-00033.parquet:   0%|          | 0.00/497M [00:00<?, ?B/s]
# train-00004-of-00033.parquet:   0%|          | 0.00/498M [00:00<?, ?B/s]
# train-00005-of-00033.parquet:   0%|          | 0.00/496M [00:00<?, ?B/s]
# train-00006-of-00033.parquet:   0%|          | 0.00/493M [00:00<?, ?B/s]
# train-00007-of-00033.parquet:   0%|          | 0.00/492M [00:00<?, ?B/s]
# train-00008-of-00033.parquet:   0%|          | 0.00/495M [00:00<?, ?B/s]
# train-00009-of-00033.parquet:   0%|          | 0.00/493M [00:00<?, ?B/s]
# train-00010-of-00033.parquet:   0%|          | 0.00/499M [00:00<?, ?B/s]
# train-00011-of-00033.parquet:   0%|          | 0.00/494M [00:00<?, ?B/s]
# train-00012-of-00033.parquet:   0%|          | 0.00/492M [00:00<?, ?B/s]
# train-00013-of-00033.parquet:   0%|          | 0.00/493M [00:00<?, ?B/s]
# train-00014-of-00033.parquet:   0%|          | 0.00/496M [00:00<?, ?B/s]
# train-00015-of-00033.parquet:   0%|          | 0.00/494M [00:00<?, ?B/s]
# train-00016-of-00033.parquet:   0%|          | 0.00/496M [00:00<?, ?B/s]
# train-00017-of-00033.parquet:   0%|          | 0.00/496M [00:00<?, ?B/s]
# train-00018-of-00033.parquet:   0%|          | 0.00/496M [00:00<?, ?B/s]
# train-00019-of-00033.parquet:   0%|          | 0.00/498M [00:00<?, ?B/s]
# train-00020-of-00033.parquet:   0%|          | 0.00/497M [00:00<?, ?B/s]
# train-00021-of-00033.parquet:   0%|          | 0.00/497M [00:00<?, ?B/s]
# train-00022-of-00033.parquet:   0%|          | 0.00/505M [00:00<?, ?B/s]
# train-00023-of-00033.parquet:   0%|          | 0.00/521M [00:00<?, ?B/s]
# train-00024-of-00033.parquet:   0%|          | 0.00/526M [00:00<?, ?B/s]
# train-00025-of-00033.parquet:   0%|          | 0.00/546M [00:00<?, ?B/s]
# train-00026-of-00033.parquet:   0%|          | 0.00/548M [00:00<?, ?B/s]
# train-00027-of-00033.parquet:   0%|          | 0.00/552M [00:00<?, ?B/s]
# train-00028-of-00033.parquet:   0%|          | 0.00/550M [00:00<?, ?B/s]
# train-00029-of-00033.parquet:   0%|          | 0.00/550M [00:00<?, ?B/s]
# train-00030-of-00033.parquet:   0%|          | 0.00/554M [00:00<?, ?B/s]
# train-00031-of-00033.parquet:   0%|          | 0.00/552M [00:00<?, ?B/s]
# train-00032-of-00033.parquet:   0%|          | 0.00/551M [00:00<?, ?B/s]
# Generating valid split:   0%|          | 0/2062 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/67376 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/34 [00:00<?, ?it/s]

# %%
print(kathbath)
# Out:
# Dataset({
#     features: ['fname', 'text', 'audio_filepath', 'lang', 'duration', 'gender', 'speaker_id'],
#     num_rows: 67376
# })

# %%
print(kathbath.column_names)
# Out:
# ['fname', 'text', 'audio_filepath', 'lang', 'duration', 'gender', 'speaker_id']

# %%
print(kathbath[0])
# Out:
# {'fname': '844424930997778-991-f.m4a', 'text': 'ಇಂದು ಬೆಳಗ್ಗೆ ಶ್ವೇತಾ ತನ್ನ ಗೆಳೆಯ ಅಮಿತ್ನನ್ನು ಭೇಟಿ ಮಾಡಲು ಹೋಟೆಲ್ಗೆ ಬಂದಿದ್ದಳು', 'audio_filepath': {'path': '844424930997778-991-f.flac', 'array': array([ 0.        ,  0.        ,  0.        , ..., -0.00059044,
#        -0.00051594, -0.00064361], shape=(78019,)), 'sampling_rate': 16000}, 'lang': 'kn', 'duration': 4.8761875, 'gender': 'Female', 'speaker_id': 991}

# %%
class KathbathProcessor:
    def __init__(self, save_dir):
        self.save_dir = save_dir
        self.audio_folder = os.path.join(save_dir, "Kathbath_kannada_audio")
        self.final_audio_folder = os.path.join(save_dir, "kannada_audios_kathbath_final")
        self.raw_csv_path = os.path.join(save_dir, "kathbath_kannada_metadata.csv")
        self.filtered_csv_path = os.path.join(save_dir, "filtered_kannada_kathbath.csv")
        os.makedirs(self.audio_folder, exist_ok=True)
        os.makedirs(self.final_audio_folder, exist_ok=True)

    def load_dataset(self):
        return load_dataset("ai4bharat/Kathbath", "kannada", split="train")

    def save_audio_and_metadata(self, dataset):
        data = []
        for idx in tqdm(range(len(dataset)), desc="Saving audio"):
            sample = dataset[idx]
            audio_array = sample["audio_filepath"]["array"]
            sr = sample["audio_filepath"]["sampling_rate"]
            duration_sec = len(audio_array) / sr
            duration_ms = duration_sec * 1000

            filename = f"kathbath_ka_{idx}.wav"
            filepath = os.path.join(self.audio_folder, filename)
            sf.write(filepath, audio_array, samplerate=sr)

            data.append({
                "audio_filename": filename,
                "text": sample["text"],
                "duration": sample["duration"],
                "duration_sec": duration_sec,
                "duration_ms": duration_ms
            })

        df = pd.DataFrame(data)
        df.to_csv(self.raw_csv_path, index=False)
        print(f" Saved metadata to {self.raw_csv_path}")
        return df

    def validate_and_update_csv(self, df):
        audio_files_set = set(os.listdir(self.audio_folder))
        unique_df = df.drop_duplicates(subset=["audio_filename"]).copy()
        unique_df["found"] = unique_df["audio_filename"].apply(lambda x: "yes" if x in audio_files_set else "no")
        unique_df.rename(columns={
            "audio_filename": "path",
            "text": "sentence"
        }, inplace=True)

        # Move 'found' after 'sentence'
        found = unique_df.pop("found")
        unique_df.insert(unique_df.columns.get_loc("sentence") + 1, "found", found)

        print(" Unique files checked and updated.")
        return unique_df

    def filter_by_duration(self, df, max_duration=15.0):
        filtered = df[df["duration_sec"] <= max_duration].copy()
        filtered.to_csv(self.filtered_csv_path, index=False)
        print(f" Filtered metadata saved to {self.filtered_csv_path}")
        return filtered

    def copy_filtered_audios(self, df):
        for fname in tqdm(df["path"], desc="Copying filtered audio files"):
            src = os.path.join(self.audio_folder, fname)
            dst = os.path.join(self.final_audio_folder, fname)
            if os.path.exists(src):
                os.system(f'cp "{src}" "{dst}"')

    def compare_duration_columns(self, df):
        if "duration" in df.columns and all(df["duration"].round(3) == df["duration_sec"].round(3)):
            print(" 'duration' and 'duration_sec' are same — dropping 'duration'")
            df = df.drop(columns=["duration"])
        else:
            print(" 'duration' and 'duration_sec' differ — keeping both")
        return df

    def summarize_csv(self, df, label=""):
        print(f"\n Summary of {label} Dataset:")
        print("-" * 40)
        print("Head:\n", df.head())
        print("\nTail:\n", df.tail())
        print("\nInfo:")
        print(df.info())
        print("\nDescribe:\n", df.describe())
        print("\nUnique 'path' count:", df["path"].nunique())

        print("\n Total Durations:")
        if "duration" in df.columns:
            print("Sum of 'duration' (sec):", df["duration"].sum())
        print("Sum of 'duration_sec':", df["duration_sec"].sum())
        print("Sum of 'duration_ms':", df["duration_ms"].sum())

        return df


processor = KathbathProcessor("/mnt/data/stt/Datasets/Datasets")
dataset = processor.load_dataset()
df_raw = processor.save_audio_and_metadata(dataset)
df_validated = processor.validate_and_update_csv(df_raw)
df_filtered = processor.filter_by_duration(df_validated)
processor.copy_filtered_audios(df_filtered)
df_final = processor.compare_duration_columns(df_filtered)
df_final = processor.summarize_csv(df_final, label="Final Filtered")

# Save final cleaned filtered CSV again (after possibly dropping column)
df_final.to_csv(processor.filtered_csv_path, index=False)
print(f"\n Final updated CSV saved to {processor.filtered_csv_path}")
# Out:
# Resolving data files:   0%|          | 0/22 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/33 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/34 [00:00<?, ?it/s]
# Saving audio: 100%|██████████| 67376/67376 [06:48<00:00, 164.90it/s]
#  Saved metadata to /mnt/data/stt/Datasets/Datasets/kathbath_kannada_metadata.csv
#  Unique files checked and updated.
#  Filtered metadata saved to /mnt/data/stt/Datasets/Datasets/filtered_kannada_kathbath.csv
# Copying filtered audio files: 100%|██████████| 66893/66893 [04:04<00:00, 273.44it/s]
#  'duration' and 'duration_sec' differ — keeping both
#
#  Summary of Final Filtered Dataset:
# ----------------------------------------
# Head:
#                  path                                           sentence found  \
# 0  kathbath_ka_0.wav  ಇಂದು ಬೆಳಗ್ಗೆ ಶ್ವೇತಾ ತನ್ನ ಗೆಳೆಯ ಅಮಿತ್ನನ್ನು ಭೇಟಿ...   yes
# 1  kathbath_ka_1.wav  ತನ್ನ ಕುಟುಂಬವೇ ಒಂದು ಭಾರತ ಎನ್ನುವುದನ್ನು ಮನದಲ್ಲಿಟ್...   yes
# 2  kathbath_ka_2.wav  ಕಾಸ್ಟ್ ಇನ್ ಪ್ಲೇಸ್ ಕಾಂಕ್ರೀಟ್ನ ವಿವಿಧ ವಸ್ತುಗಳ ನಡು...   yes
# 3  kathbath_ka_3.wav  ಜೊತೆಗೆ ಅರ್ಧ ಕೇರಳವು ಕಂಡು ಕೇಳರಿಯದ ಪ್ರವಾಹಕ್ಕೆ ಸಿಕ...   yes
# 4  kathbath_ka_4.wav  ಒಟ್ಟಾರೆ ವರ್ಲ್ಡ್ ಟೂರ್ ಸ್ಪರ್ಧೆಗಳಲ್ಲಿ ನಾಲ್ಕು ಬಾರಿ...   yes
#
#    duration  duration_sec  duration_ms
# 0  4.876188      4.876188    4876.1875
# 1  7.035687      7.035687    7035.6875
# 2  6.315812      6.315812    6315.8125
# 3  5.921125      5.921125    5921.1250
# 4  5.735313      5.735313    5735.3125
#
# Tail:
#                          path  \
# 67371  kathbath_ka_67371.wav
# 67372  kathbath_ka_67372.wav
# 67373  kathbath_ka_67373.wav
# 67374  kathbath_ka_67374.wav
# 67375  kathbath_ka_67375.wav
#
#                                                 sentence found   duration  \
# 67371  ಏಕಮಾತ್ರ ಸ್ವಾಮ್ಯತ್ವವನ್ನು ಅದರ ಸರಳತೆ ಸೆಟಪ್ ಸುಲಭ ಮ...   yes  10.565062
# 67372  ಆ ಸಮಯದಲ್ಲಿದ್ದ ಅತ್ಯಂತ ಮೆಚ್ಚುಗೆ ಪಡೆದ ಭಾರತದ ಚಲನಚಿ...   yes   9.055813
# 67373  ಕೊನೆಗೆ ಅದರ ಆಧುನಿಕ ರೂಪ ಚೇಸ್ತು ಉಂಡುನು ಎಂದಾಗಿದೆ ಮ...   yes   8.498500
# 67374  ಪುಟ್ಟ ಪುಟ್ಟ ಕಂದಮ್ಮಗಳು ತಮ್ಮ ಮುದ್ದಾದ ಕಾಲುಗಳಿಗೆ ತ...   yes  10.425750
# 67375  ಒಂದು ಕಾಲದಲ್ಲಿ ಪ್ರಸಿದ್ಧವಾಗಿದ್ದ ಹೀರೊ ಅಂಡ್ ಹೀರೊವರ...   yes  10.727625
#
#        duration_sec  duration_ms
# 67371     10.565062   10565.0625
# 67372      9.055813    9055.8125
# 67373      8.498500    8498.5000
# 67374     10.425750   10425.7500
# 67375     10.727625   10727.6250
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66893 entries, 0 to 67375
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   path          66893 non-null  object
#  1   sentence      66893 non-null  object
#  2   found         66893 non-null  object
#  3   duration      66893 non-null  float64
#  4   duration_sec  66893 non-null  float64
#  5   duration_ms   66893 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 3.6+ MB
# None
#
# Describe:
#             duration  duration_sec  duration_ms
# count  66893.000000  66893.000000  66893.00000
# mean       7.710629      7.710629   7710.62934
# std        1.942813      1.942813   1942.81349
# min        0.812688      0.812688    812.68750
# 25%        6.292625      6.292625   6292.62500
# 50%        7.430375      7.430375   7430.37500
# 75%        8.846813      8.846813   8846.81250
# max       14.976875     14.976875  14976.87500
#
# Unique 'path' count: 66893
#
#  Total Durations:
# Sum of 'duration' (sec): 515787.12843750004
# Sum of 'duration_sec': 515787.12843750004
# Sum of 'duration_ms': 515787128.4375
#
#  Final updated CSV saved to /mnt/data/stt/Datasets/Datasets/filtered_kannada_kathbath.csv

# %% [markdown]
# **Dropping duration column from the fitered file**

# %%
csv_path = "/mnt/data/stt/Datasets/Datasets/filtered_kannada_kathbath.csv" # Load the CSV file
df = pd.read_csv(csv_path)


print(f" Total columns before dropping: {df.shape[1]}") # Show total number of columns before dropping
print(" Column names:", df.columns.tolist())


if 'duration' in df.columns: # Drop the 'duration' column if it exists
    df.drop(columns=['duration'], inplace=True)
    print(" 'duration' column dropped.")
else:
    print(" 'duration' column not found.")


print(f" Total columns after dropping: {df.shape[1]}") # Show total columns after dropping
print(" Updated column names:", df.columns.tolist())
# Out:
#  Total columns before dropping: 6
#  Column names: ['path', 'sentence', 'found', 'duration', 'duration_sec', 'duration_ms']
#  'duration' column dropped.
#  Total columns after dropping: 5
#  Updated column names: ['path', 'sentence', 'found', 'duration_sec', 'duration_ms']

# %%
df.to_csv(csv_path, index=False)
print(" Updated CSV saved.")
# Out:
#  Updated CSV saved.

# %% [markdown]
# **For updated audio folders**

# %%
audio_folder = "/mnt/data/stt/Datasets/Datasets/kannada_audios_kathbath_final"
# List all .wav files
audio_files = [f for f in os.listdir(audio_folder) if f.endswith(".wav")]
# Count them
print(f" Total number of audio files: {len(audio_files)}")
# Out:
#  Total number of audio files: 66893

# %%
import os
from IPython.display import Audio
audio_files = sorted(os.listdir(audio_folder))[:5]  # first 5 files
for file in audio_files:
    print(f" Playing: {file}")
    display(Audio(filename=os.path.join(audio_folder, file)))
# Out:
#  Playing: kathbath_ka_0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Playing: kathbath_ka_1.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Playing: kathbath_ka_10.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Playing: kathbath_ka_100.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  Playing: kathbath_ka_1000.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
